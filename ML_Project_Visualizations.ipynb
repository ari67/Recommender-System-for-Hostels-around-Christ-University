# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("D:\\ML project\\PG RECOMMENDATION SYSTEM (Responses) - Form responses 1.csv")

# %%
data.head()
# Out:
#              Timestamp  Name (Optional)  Age  Gender Place hailing from  \
# 0  01/04/2023 22:25:20          Shebin    21    Male             Kerala
# 1  01/04/2023 22:26:40             Arya   22  Female             Kerala
# 2  01/04/2023 22:26:43  Anandhalakshmi    22  Female             Kerala
# 3  01/04/2023 22:53:33           Nidin    21    Male         Tamil Nadu
# 4  01/04/2023 23:05:14     Rishav Laloo   23    Male          Meghalaya
#
#   Name of the Hostel Category                                   Type  \
# 0            KE Hall     Boys  Hostels run by Christian missionaries
# 1    Augustine Nivas    Girls  Hostels run by Christian missionaries
# 2    Augustine Nivas    Girls  Hostels run by Christian missionaries
# 3            KE Hall     Boys                         Normal Hostels
# 4            KE Hall     Boys  Hostels run by Christian missionaries
#
#   Distance from College:                   Location  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 31 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Timestamp                                                     200 non-null    object
#  1   Name (Optional)                                               119 non-null    object
#  2   Age                                                           200 non-null    int64
#  3   Gender                                                        200 non-null    object
#  4   Place hailing from                                            200 non-null    object
#  5   Name of the Hostel                                            200 non-null    object
#  6   Category                                                      200 non-null    object
# ...

# %% [markdown]
# ## Inferenece: The null values in food section must be handled

# %%
data.shape
# Out:
# (200, 31)

# %%
data.describe()
# Out:
#               Age  Rate the atmosphere around the hostel:  \
# count  200.000000                              200.000000
# mean    21.900000                                3.630000
# std      3.327969                                1.071842
# min     18.000000                                1.000000
# 25%     21.000000                                3.000000
# 50%     22.000000                                4.000000
# 75%     22.000000                                4.250000
# max     62.000000                                5.000000
#
#        On a scale of 1 to 5, how strict is the hostel/PG  \
# count                                         200.000000
# mean                                            2.865000
# std                                             1.366055
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data.drop(['Name (Optional)','Timestamp','Comments/Remarks/Suggestions related to hostel/PG'],axis =1, inplace = True)
# removing unrelevant features for the study
# feature scaling

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %%
data['Name of the Hostel']
# Out:
# 0                KE Hall
# 1        Augustine Nivas
# 2        Augustine Nivas
# 3                KE Hall
# 4                KE Hall
#              ...
# 195        Vaayu Hostels
# 196           C Comforts
# 197         Nesto Charan
# 198    Cst vidhya bhavan
# 199    Cst vidhya bhavan
# Name: Name of the Hostel, Length: 200, dtype: object

# %%
# removing trailing whitespaces
white_space = data['Name of the Hostel'].str.endswith(" ").any()
if white_space:
    print("White space exists")
else:
    print("White space doesnt exist")
# Out:
# White space exists

# %%
data['Name of the Hostel'] = data['Name of the Hostel'].apply(str.rstrip)
#The .apply() method in pandas is used to apply a function to each element of a pandas Series or DataFrame

# %%
# verifying
# removing trailing whitespaces
white_space = data['Name of the Hostel'].str.endswith(" ").any()
if white_space:
    print("White space exists")
else:
    print("White space doesnt exist")
# Out:
# White space doesnt exist

# %%
#CONVERTING ALL HOSTEL NAMES TO LOWER CASE:

data['Name of the Hostel'] = data['Name of the Hostel'].str.lower()

# %%
# FINDING THE NUMBER OF HOSTELS WHOSE DATA WE HAVE COLLECTED.
data["Name of the Hostel"].nunique()
# nunique() method is used to count the number of unique values in the specified column of the DataFrame
# Out:
# 93

# %%
data["Name of the Hostel"].unique()
# Out:
# array(['ke hall', 'augustine nivas', 'stanza living',
#        'gayathri luxury pg', 'providence convent', 'besania study house',
#        'jonas hall', 'nil', 'pelagia hostel', 'sri sai pg for ladies',
#        'malabar plaza', 'savina bhavan', 'young india pg',
#        'ankalamma pg for ladies', 'vijalakshmi', 'joseph pg for ladies',
#        'lakshmi venkateshwara pg', 'joseph’s pg', 'aishwarya sunshine pg',
#        'sri omkareshwara pg', 'sri lakshmi venkateshwara pg for girls',
#        'happy homes hostel', 'vaibhava pg', 'caritas study house',
#        'sannidhana', 'slv pg', 'shree hostel', 'sapthagiri',
#        'venkateshwara pg', 'serenity', 'besania hostel',
#        'new sri krishna krupa pg', 'providence covent hostel',
#        'cst vidhya bhavan', 'snehadan', 'aishwarya pg',
#        'yuva vikas hostel', 'adler', 'providence convent hostel',
#        'comfort luxury', 'yuvi', 'prashanti study house',
#        'svr pg for ladies', 'ankalamma', 'puzzles living',
# ...

# %%
ke = data.loc[data['Name of the Hostel'].str.startswith('k'), 'Name of the Hostel']

# %%
print(ke.unique())
# Out:
# ['ke hall' 'kms  elite']

# %%
# since some of them are just the same hostels but written in different formats, convert into a single name.

data['Name of the Hostel'] = data['Name of the Hostel'].replace('', 'not given')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('joseph’s pg', 'joseph pg for ladies')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('sri lakshmi venkateshwara pg', 'sri lakshmi venkateshwara pg for girls')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('lakshmi venkateshwara pg', 'sri lakshmi venkateshwara pg for girls')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('sri lakshmi venkateshwara', 'sri lakshmi venkateshwara pg for girls')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('besania hostel', 'besania study house')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('providence covent hostel', 'providence convent')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('ankalamma', 'ankalamma pg for ladies')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('slv pg', 'slv ladies pg')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('agustine nivas', 'augustine nivas')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('yashmitha', 'yashmitha pg')
data['Name of the Hostel'] = data['Name of the Hostel'].replace(['sannidhana', 'sannidhana girls hostel', 'sannidhana study house sabs'], 'sannidhana study house')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('zolo maple', 'zolo mapple')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('stanza living frankfurt', 'stanza living frankfurt house')
data['Name of the Hostel'] = data['Name of the Hostel'].replace('aishwarya sunshine hostel', 'aishwarya sunshine pg')

data['Name of the Hostel'].unique()
# Out:
# array(['ke hall', 'augustine nivas', 'stanza living',
#        'gayathri luxury pg', 'providence convent', 'besania study house',
#        'jonas hall', 'nil', 'pelagia hostel', 'sri sai pg for ladies',
#        'malabar plaza', 'savina bhavan', 'young india pg',
#        'ankalamma pg for ladies', 'vijalakshmi', 'joseph pg for ladies',
#        'sri lakshmi venkateshwara pg for girls', 'aishwarya sunshine pg',
#        'sri omkareshwara pg', 'happy homes hostel', 'vaibhava pg',
#        'caritas study house', 'sannidhana study house', 'slv ladies pg',
#        'shree hostel', 'sapthagiri', 'venkateshwara pg', 'serenity',
#        'new sri krishna krupa pg', 'cst vidhya bhavan', 'snehadan',
#        'aishwarya pg', 'yuva vikas hostel', 'adler',
#        'providence convent hostel', 'comfort luxury', 'yuvi',
#        'prashanti study house', 'svr pg for ladies', 'puzzles living',
#        'myroomie camellia', 'svr pg', 'puzzles hope house',
# ...

# %%
data['Name of the Hostel'].nunique()
# Out:
# 77

# %%
data['Location'].unique()
# Out:
# array(['CHRIST UNIVERSITY ', 'Kaveri Layout', 'Kaveri layout ',
#        'Inside Christ University ', 'Christ University', '8th cross',
#        'Bangalore ', 'Tavarekere ', 'Christ University ', 'SG palya',
#        'Koramangala', 'inside university', 'SG Palya',
#        'Near Christ ICSE school', 'SG Palaya', 'S G Palya ',
#        'SG Palya, Above Jose Mess, 1st Main', '6th cross, sg palya',
#        'SG palaya ', 'Bangalore', '1st cross road-Bharathi Layout',
#        "St John's apartments ", 'Chikku Lakshmaiah Layout ',
#        '19, 1st Cross Rd, Tavarekere, Bhavani Nagar, S.G. Palya, Bengaluru, Karnataka 560029',
#        'Bharti Layout ', 'S.G Palya', 'Btm layout 1 st stage',
#        'CL Layout ', '2nd cross, bharti layout, sg palaya', 'mysore',
#        'Bharathi Layout, SG Palya', 'SG PALYA ', 'Sg palya',
#        'Malabar Cafe', 'S.G. palya ',
#        'S.G Palaya, Hosur road, Bangalore.',
#        "S G palya , near St John's apartment ", 'SG palaya', 'Karnataka ',
# ...

# %%
data['Location'].unique()
# Out:
# array(['CHRIST UNIVERSITY ', 'Kaveri Layout', 'Kaveri layout ',
#        'Inside Christ University ', 'Christ University', '8th cross',
#        'Bangalore ', 'Tavarekere ', 'Christ University ', 'SG palya',
#        'Koramangala', 'inside university', 'SG Palya',
#        'Near Christ ICSE school', 'SG Palaya', 'S G Palya ',
#        'SG Palya, Above Jose Mess, 1st Main', '6th cross, sg palya',
#        'SG palaya ', 'Bangalore', '1st cross road-Bharathi Layout',
#        "St John's apartments ", 'Chikku Lakshmaiah Layout ',
#        '19, 1st Cross Rd, Tavarekere, Bhavani Nagar, S.G. Palya, Bengaluru, Karnataka 560029',
#        'Bharti Layout ', 'S.G Palya', 'Btm layout 1 st stage',
#        'CL Layout ', '2nd cross, bharti layout, sg palaya', 'mysore',
#        'Bharathi Layout, SG Palya', 'SG PALYA ', 'Sg palya',
#        'Malabar Cafe', 'S.G. palya ',
#        'S.G Palaya, Hosur road, Bangalore.',
#        "S G palya , near St John's apartment ", 'SG palaya', 'Karnataka ',
# ...

# %%
n_locn = data['Location'].nunique()
n_locn
# Out:
# 140

# %%
replace_locn_sgpalya =['SG palya','SG Palya','SG Palaya','S G Palya ','SG Palya',"6th cross, sg palya","SG palaya ","S.G. Palya","S.G Palya","2nd cross, bharti layout, sg palaya","Bharathi Layout, SG Palya","SG PALYA ", "Sg palya","S.G. palya ",
      "S.G Palaya, Hosur road, Bangalore.'","S G palya , near St John's apartment ",'SG palaya',"Near Christ ICSE School SG Palaya, Bangalore",'S. G. Palya','SG Palaya ','S G palaya ',"Venkateshwara Layout, SG Palya, Hosur road, Bangalore","SG Palya, Banglore ",'SG Palya ','Sg palya ','6th cross sg palya','S G Palya', 'Sg palaya','SG palya road',"SG Palya, Bangalore ",'S G palaya',"Sg palya, 1st cross. ",'S.G palya','SG PALYA','S G palya ', "SG Palya, Near Christ ICSE School ",'S G Playa']

# %%
crct_locn_sgpalya = "S.G Palya"

# %%
data['Location'] = data['Location'].replace(replace_locn_sgpalya, crct_locn_sgpalya)

# %%
data['Location'].nunique()
# Out:
# 107

# %% [markdown]
# ## PREPROCESSING ROOM TYPE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %%
data['Room Type:'].unique()
# Out:
# array(['Three-Sharing', 'Two-Sharing', 'Four-Sharing', 'Single',
#        '2/4/6 Sharing', 'Single ', 'Two sharing special room daaaa!!!!',
#        'All', 'Single, two sharing and 3 sharing '], dtype=object)

# %%
room_type_replace = ['Two sharing special room daaaa!!!!','2/4/6 Sharing','All',"Single, two sharing and 3 sharing "]

# %%
data[data['Room Type:'] == 'All']
# Out:
#      Age Gender Place hailing from Name of the Hostel Category Type  \
# 109   20   Male          Karnataka         sapthagiri     Boys  PGs
#
#     Distance from College:                                           Location  \
# 109       Less than 500 ms  SG palaya first main road, near Christ main gate.
#
#     Does your PG/hostel provide mess facility?  \
# 109                                        Yes
#
#     If yes, what type of food do they provide?  ...  \
# 109                               North Indian  ...
#
#     Curfew (By what time you have to reach hostel)  \
# 109                                      No curfew
#
#                                   Appliances available  \
# 109  Washing machine, Referigerator, Induction cook...
#
#                                     Appliances allowed  \
# 109  Iron box, Kettle, Air frier, Hair drier/Straig...
#
#      Rate the atmosphere around the hostel:  \
# 109                                       5
#
# ...

# %%
data[data['Name of the Hostel'] == 'sapthagiri']
# Out:
#      Age Gender Place hailing from Name of the Hostel Category Type  \
# 43    22   Male         Tamil Nadu         sapthagiri     Boys  PGs
# 109   20   Male          Karnataka         sapthagiri     Boys  PGs
#
#     Distance from College:                                           Location  \
# 43        Less than 500 ms                                          S.G Palya
# 109       Less than 500 ms  SG palaya first main road, near Christ main gate.
#
#     Does your PG/hostel provide mess facility?  \
# 43                                         Yes
# 109                                        Yes
#
#     If yes, what type of food do they provide?  ...  \
# 43                                North Indian  ...
# 109                               North Indian  ...
#
#     Curfew (By what time you have to reach hostel)  \
# 43                                       No curfew
# 109                                      No curfew
#
# ...

# %%
data[data['Room Type:'] == "Single, two sharing and 3 sharing "]
# Out:
#      Age  Gender Place hailing from     Name of the Hostel Category Type  \
# 150   26  Female          Karnataka  aishwarya sunshine pg    Girls  PGs
#
#     Distance from College:   Location  \
# 150         500 ms to 1 km  S.G Palya
#
#     Does your PG/hostel provide mess facility?  \
# 150                                        Yes
#
#     If yes, what type of food do they provide?  ...  \
# 150                               South Indian  ...
#
#     Curfew (By what time you have to reach hostel)  \
# 150                            10:00 pm - 11:00 pm
#
#                                   Appliances available  \
# 150  Washing machine, Referigerator, Induction cook...
#
#                                     Appliances allowed  \
# 150  Iron box, Kettle, Hair drier/Straightner, Indu...
#
#      Rate the atmosphere around the hostel:  \
# 150                                       5
#
#     On a scale of 1 to 5, how strict is the hostel/PG  \
# ...

# %%
data[data['Name of the Hostel'] == 'aishwarya sunshine pg']
# Out:
#      Age  Gender Place hailing from     Name of the Hostel Category Type  \
# 32    22  Female          Karnataka  aishwarya sunshine pg    Girls  PGs
# 150   26  Female          Karnataka  aishwarya sunshine pg    Girls  PGs
#
#     Distance from College:   Location  \
# 32        Less than 500 ms  S.G Palya
# 150         500 ms to 1 km  S.G Palya
#
#     Does your PG/hostel provide mess facility?  \
# 32                                         Yes
# 150                                        Yes
#
#     If yes, what type of food do they provide?  ...  \
# 32                                South Indian  ...
# 150                               South Indian  ...
#
#     Curfew (By what time you have to reach hostel)  \
# 32                             10:00 pm - 11:00 pm
# 150                            10:00 pm - 11:00 pm
#
#                                   Appliances available  \
# 32   Washing machine, Referigerator, Induction cook...
# ...

# %%
room_type_new = "Two-Sharing"

# %%
data['Room Type:'] = data['Room Type:'].replace(room_type_replace,room_type_new)

# %%
data['Room Type:'].unique()
# Out:
# array(['Three-Sharing', 'Two-Sharing', 'Four-Sharing', 'Single',
#        'Single '], dtype=object)

# %%
data['Room Type:'] = data['Room Type:'].replace('Single ','Single')

# %%
data['Room Type:'].unique()
# Out:
# array(['Three-Sharing', 'Two-Sharing', 'Four-Sharing', 'Single'],
#       dtype=object)

# %% [markdown]
# ## PREPROCESSING FEES PER MONTH FEATURE

# %%
data['Fees per month']
# Out:
# 0       4,500
# 1      11,500
# 2        8000
# 3       4,500
# 4        5000
#         ...
# 195      9000
# 196     16000
# 197      6000
# 198      6800
# 199      6800
# Name: Fees per month, Length: 200, dtype: object

# %%
data['Fees per month'].dtype
# Out:
# dtype('O')

# %%
data['Fees per month'] = data['Fees per month'].str.replace('/-','').str.replace(',','').str.replace('Rs. ','').astype(float)
# Out:
# <ipython-input-29-a5d0cfff6703>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Fees per month'] = data['Fees per month'].str.replace('/-','').str.replace(',','').str.replace('Rs. ','').astype(float)

# %%
data['Fees per month']
# Out:
# 0       4500.0
# 1      11500.0
# 2       8000.0
# 3       4500.0
# 4       5000.0
#         ...
# 195     9000.0
# 196    16000.0
# 197     6000.0
# 198     6800.0
# 199     6800.0
# Name: Fees per month, Length: 200, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %% [markdown]
# ### Handling missing value is not required for the columns If yes, what type of food do they provide?,Food type since the missing values are not given as random

# %% [markdown]
# # EDA

# %%
# visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# count the frequency of each category
counts = data['Type'].value_counts()

# create a pie chart of the frequency counts
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85, textprops={'fontsize': 12})
plt.title('Distribution of Types of Hostels', fontsize=16)

# display the chart
plt.show()

# %%
# count the frequency of each category
counts = data['Distance from College:'].value_counts()

# create a pie chart of the frequency counts
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
colors = ['#ff9999','#66b3ff','#99ff99']
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%',colors=colors, startangle=90, pctdistance=0.85, textprops={'fontsize': 12})
plt.title('Distance From College of the data collected', fontsize=16)

# display the chart
plt.show()

# %%
sns.histplot(data=data, x='Fees per month', bins=10, color='green')

# set the title and axis labels
plt.title('Histogram of Fees per month')
plt.xlabel('Fees per month')
plt.ylabel('Frequency')

# display the plot
plt.show()

# %%
sns.countplot(x="On a scale of 1 to 5, select the overall rating", data=data)
# Out:
# <AxesSubplot:xlabel='On a scale of 1 to 5, select the overall rating', ylabel='count'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %%
# Create stacked bar chart using seaborn
sns.catplot(x="Curfew (By what time you have to reach hostel)", hue="Distance from College:", kind="count", data=data,height=8, aspect=1.5)

# %%
# Calculate counts for each combination of class and sex
counts = data.groupby(["Distance from College:", "Curfew (By what time you have to reach hostel)"]).size().unstack()

# Create heatmap using matplotlib
fig, ax = plt.subplots(figsize=(20, 10))
im = ax.imshow(counts, cmap="YlGn")
ax.set_xticks(np.arange(len(counts.columns)))
ax.set_yticks(np.arange(len(counts.index)))
ax.set_xticklabels(counts.columns)
ax.set_yticklabels(counts.index)
plt.colorbar(im)
plt.show()

# %%
counts = data.groupby(["Distance from College:", "Curfew (By what time you have to reach hostel)"]).size().unstack()

# Create heatmap using Seaborn
ax = sns.heatmap(counts, cmap="YlGnBu", annot=True)

# Set plot title and axis labels
ax.set_title("Curfew and Distance")
ax.set_xlabel("Curfew (By what time you have to reach hostel)")
ax.set_ylabel("Distance from College:")

# Show plot
plt.show()

# %%
# Create box plot using Seaborn
ax = sns.boxplot(x="Distance from College:", y="Fees per month", data=data)

# Set plot title and axis labels
ax.set_title("Whether Distance from college affects the fees per month")
ax.set_xlabel("Distance from College")
ax.set_ylabel("Fees per month")

# Show plot
plt.show()

# %%
# Create violin plot using Seaborn
ax = sns.violinplot(x="Distance from College:", y="Fees per month", data=data)

# Set plot title and axis labels
ax.set_title("Whether Distance from college affects the fees per month")
ax.set_xlabel("Distance from College")
ax.set_ylabel("Fees per month")

# Show plot
plt.show()

# %% [markdown]
# ### HOSTEL'S AND THEIR FEE PATTERN

# %%
colors = ['#006D77', '#83C5BE', '#EDAE49', '#D1495B', '#4B4453']
plt.figure(figsize=(10,6))
ax = sns.boxplot(x="Name of the Hostel", y="Fees per month", data=data, palette=colors, linewidth=2.5, fliersize=6)
# Add labels and title
plt.xlabel("Hostel Name", fontsize=12)
plt.ylabel("Fees per month", fontsize=12)
plt.title("Distribution of Hostel Fees", fontsize=16)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Remove top and right spines
sns.despine(top=True, right=True)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %%
data['Location'].unique
# Out:
# <bound method Series.unique of 0             CHRIST UNIVERSITY
# 1                  Kaveri Layout
# 2                 Kaveri layout
# 3      Inside Christ University
# 4              Christ University
#                  ...
# 195                    S.G Palya
# 196           Kormangala Block 6
# 197                    S.G Palya
# 198      Opposite christ school
# 199      Opposite christ school
# Name: Location, Length: 200, dtype: object>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Location', data=data)
plt.xticks(rotation=45)
plt.title('Frequency of Hostel Locations')
plt.show()

# %%
top_locations = data['Location'].value_counts().nlargest(10).index.tolist()

plt.figure(figsize=(12, 6))
sns.countplot(x='Location', data=data, order=top_locations)
plt.title('top 10 most frequent locations ')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### TYPE OF HOSTELS AND THEIR RESTRICTIONS

# %%
sns.catplot(x="Curfew (By what time you have to reach hostel)", hue="Type", kind="count", data=data,height=8, aspect=1.5)

# %% [markdown]
# ## From this we can infer
# * HOSTELS RUN BY CHRISTIAN MISSIONARIES are more strict for their curfew timings
# * in PG's we get more relaxation on curfew timings

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %% [markdown]
# ## ROOM TYPE

# %%
# Count the frequency of each category in the 'Room Type' variable
room_type_counts = data['Room Type:'].value_counts()

# %%
sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(10,6)})

sns.countplot(x="Room Type:", data=data, order=data['Room Type:'].value_counts().index, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='Room Type:', ylabel='count'>

# %%
# Find the category with the most occurrences
most_common_room_type = room_type_counts.index[0]
print("The most common room type is:", most_common_room_type)
# Out:
# The most common room type is: Two-Sharing

# %% [markdown]
# ## TYPE OF HOSTEL AND FEE STRUCTURE

# %%
sns.set_style("whitegrid")
sns.set_palette("Set2")

fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="Type", y="Fees per month", data=data, ci=None, ax=ax)
ax.set_xlabel("Type of Hostel", fontsize=12)
ax.set_ylabel("Fees per month (in Rs)", fontsize=12)
ax.set_title("Comparison of fees per month for different types of hostels", fontsize=14)
plt.show()

# %% [markdown]
# ## TYPE OF HOSTEL IN WHICH PARKING IS AVAILABLE

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(10,6))
sns.countplot(x="Type", hue="Is Parking available", data=data, palette="Set2")

plt.title("Relationship between Type of Hostel and Parking Availability")
plt.xlabel("Type of Hostel")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## STRICTNESS OF HOSTELS

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 20))
sns.barplot(x="On a scale of 1 to 5, how strict is the hostel/PG", y="Name of the Hostel", data=data, ci=None, palette="Set2")
plt.title("Strictness Rating of Hostels")
plt.xlabel("Count")
plt.ylabel("Hostel Name")
# Out:
# Text(0, 0.5, 'Hostel Name')

# %% [markdown]
# ## THE TOP STRICT HOSTELS

# %%
# Plot countplot
plt.figure(figsize=(20,10))
ax = sns.countplot(x="Name of the Hostel", hue="On a scale of 1 to 5, how strict is the hostel/PG", data=data, order=data['Name of the Hostel'].value_counts().iloc[:10].index, palette="Set1")

# Set title and axis labels
plt.title("Strictness level of top 10 hostels", fontsize=14)
plt.xlabel("Hostel name", fontsize=12)
plt.ylabel("Count", fontsize=12)

# Show the plot
plt.show()

# Find top 5 strict hostels
top_strict_hostels = data[data["On a scale of 1 to 5, how strict is the hostel/PG"] == 5]["Name of the Hostel"].value_counts().head(5)

# Print top 5 strict hostels
print("Top 5 strict hostels:\n")
print(top_strict_hostels)
# Out:
# Top 5 strict hostels:
#
# ke hall                   21
# jonas hall                 7
# augustine nivas            3
# sannidhana study house     3
# besania study house        1
# Name: Name of the Hostel, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %%
data['Curfew (By what time you have to reach hostel)'].unique()
# Out:
# array(['9:00 pm - 10:00 pm', '10:00 pm - 11:00 pm', 'No curfew',
#        '8:00 pm - 9:00 pm', '7:00 pm - 8:00 pm'], dtype=object)

# %% [markdown]
# ## HOSTELS BASED ON CLEANLINESS FACTOR

# %%
sns.set(style="whitegrid")
cleanliness_data = data[['Name of the Hostel', 'On a scale of 1 to 5, how do you rate the hostel cleanliness']]
cleanliness_data = cleanliness_data.groupby(['Name of the Hostel'])['On a scale of 1 to 5, how do you rate the hostel cleanliness'].mean().reset_index()

# sort the data in descending order based on cleanliness rating
cleanliness_data = cleanliness_data.sort_values(by='On a scale of 1 to 5, how do you rate the hostel cleanliness', ascending=False)

# plot the data
plt.figure(figsize=(12, 8))
sns.barplot(x='Name of the Hostel', y='On a scale of 1 to 5, how do you rate the hostel cleanliness', data=cleanliness_data)
plt.xticks(rotation=90)
plt.xlabel('Hostel Name')
plt.ylabel('Cleanliness Rating')
plt.title('Hostel Cleanliness Ratings')
plt.show()

# %% [markdown]
# ## THE TOP 5 HOSTELS WHICH ARE RATED FOR CLEANLINESS

# %%
# Create a countplot to visualize the distribution of cleanliness ratings by hostel
plt.figure(figsize=(10, 6))
sns.countplot(x="Name of the Hostel", hue="On a scale of 1 to 5, how do you rate the hostel cleanliness",
              data=data, order=data["Name of the Hostel"].value_counts().index[:5])

# Set plot title and axis labels

plt.title("Top 10 Hostels by Cleanliness Rating")
plt.xlabel("Hostel Name")
plt.ylabel("Number of Ratings")

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Adjust position of x-axis labels
plt.gca().set_xticklabels(data["Name of the Hostel"].value_counts().index[:5], rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# ## OVERALL RATING OF THE HOSTELS AND CURFEW TIMING

# %%
# Create a contingency table
ct = pd.crosstab(data['Curfew (By what time you have to reach hostel)'], data['On a scale of 1 to 5, select the overall rating'])

# Plot heatmap of the contingency table
sns.heatmap(ct, annot=True, cmap='YlGnBu')

# Set plot title and axis labels
plt.title("Overall Rating vs Curfew")
plt.xlabel("Overall Rating")
plt.ylabel("Curfew")

# Show the plot
plt.show()

# %%
# Create a cross tabulation of the two categorical variables
cross_tab = pd.crosstab(data["On a scale of 1 to 5, select the overall rating"], data["Curfew (By what time you have to reach hostel)"])

# Plot the stacked bar chart
cross_tab.plot(kind="bar", stacked=True, figsize=(8,6))

# Set plot title and axis labels
plt.title("Overall Rating vs Curfew")
plt.xlabel("Overall Rating")
plt.ylabel("Number of Hostels")

# Show the plot
plt.show()

# %% [markdown]
# ## CHI-SQUARE TEST

# %%
from scipy.stats import chi2_contingency

# Create a contingency table of the two categorical variables
contingency_table = pd.crosstab(data['On a scale of 1 to 5, select the overall rating'],
                                data['Curfew (By what time you have to reach hostel)'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results of the chi-square test
print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 17.809871059171947
# p-value: 0.33514750004567434

# %% [markdown]
# ### Here p-value is 0.3351 which is greater than 0.05 therefore we fail to reject the null hypothesis, ie there is no significant relationship between the two categorical variables overall ratings and curfew timing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 28 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Age                                                           200 non-null    int64
#  1   Gender                                                        200 non-null    object
#  2   Place hailing from                                            200 non-null    object
#  3   Name of the Hostel                                            200 non-null    object
#  4   Category                                                      200 non-null    object
#  5   Type                                                          200 non-null    object
#  6   Distance from College:                                        200 non-null    object
# ...

# %% [markdown]
# ## OVERALL RATING VS DISTANCE FROM COLLEGE

# %%
# Create a cross-tabulation of the two variables
ct = pd.crosstab(data["On a scale of 1 to 5, select the overall rating"],
                 data["Distance from College:"])

# Normalize the counts to create percentages
ct_pct = ct.apply(lambda r: r/r.sum()*100, axis=1)

# Create a stacked bar chart of the cross-tabulation
ct_pct.plot(kind="bar", stacked=True, figsize=(10, 6))

# Set plot title and axis labels
plt.title("Overall Rating vs Distance from College")
plt.xlabel("Overall Rating")
plt.ylabel("Percentage")

# Show the plot
plt.show()

# %% [markdown]
# ## INFERENCE
# ### From the stacked bar chart, we can infer that:
#
# * Majority of the hostels with a rating of 5 have a distance from college of less than 500m, and very few have a distance of more than 1km.
# * For hostels with a rating of 4 or less, the distribution of distances from college is more spread out.
# * Overall, hostels with better ratings tend to be located closer to the college, with a higher proportion having a distance of less than 500m.

# %% [markdown]
# ## TOP RATED HOSTELS BASED ON OVERALL RATINGS

# %%
# Set the figure size
plt.figure(figsize=(10,6))

# Create a bar plot to visualize the overall ratings by hostel
sns.countplot(x="Name of the Hostel", hue="On a scale of 1 to 5, select the overall rating",
              data=data, order=data["Name of the Hostel"].value_counts().index[:5])

# Set plot title and axis labels
plt.title("Top 5 Hostels by Overall Rating")
plt.xlabel("Hostel Name")
plt.ylabel("Number of Ratings")

# Rotate x-axis labels for readability
plt.xticks(rotation=45)

# Add legend outside the plot
plt.legend(title="Overall Rating", bbox_to_anchor=(1, 1), loc='upper left')

# Remove top and right spines and set grid lines to white for better visibility
sns.despine(top=True, right=True, left=False, bottom=False)
plt.grid(axis='y', color='white')

# Set background color
plt.gca().set_facecolor('#F5F5F5')

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# ## OVERALL RATINGS VS TYPE OF HOSTEL

# %%
# Create a countplot to visualize the distribution of overall ratings by hostel type
plt.figure(figsize=(10, 6))

sns.countplot(x="Type", hue="On a scale of 1 to 5, select the overall rating",
              data=data)

# Set plot title and axis labels
plt.title("Overall Ratings by Hostel Type")
plt.xlabel("Hostel Type")
plt.ylabel("Number of Ratings")

# Show the plot
plt.show()

# %%
# Create a bar plot to visualize the average rating by hostel type
plt.figure(figsize=(10, 6))

sns.set_style("whitegrid")
sns.set_palette("Set2")
sns.barplot(x="Type", y="On a scale of 1 to 5, select the overall rating", data=data)

# Set plot title and axis labels
plt.title("Average Rating by Hostel Type")
plt.xlabel("Hostel Type")
plt.ylabel("Average Rating")

# Show the plot
plt.show()
